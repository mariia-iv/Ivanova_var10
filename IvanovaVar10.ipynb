# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#зададим аргумент и модуль комплексного числа
phi = np.linspace(0, 10*np.pi, 400)
rho = 0.9*abs(np.cos(3/5 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))

#построение исходной розы
plt.plot(z.real, z.imag, color = 'blue', linewidth = 0.8)

plt.xlabel("Re(z)")
plt.ylabel("Im(z)")

#построение границы исходной розы
phi_1 = np.linspace(-np.pi/6, np.pi/6, 50)
rho = 0.9*abs(np.cos(3/5 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'blue', linewidth = 3)

phi_2 = np.linspace((-np.pi/6 + 5/3 * np.pi), (np.pi/6 + 5/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_2))
z = rho * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'blue', linewidth = 3)

phi_3 = np.linspace((-np.pi/6 + 10/3 * np.pi), (np.pi/6 + 10/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_3))
z = rho * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'blue', linewidth = 3)

phi_4 = np.linspace((-np.pi/6 + 15/3 * np.pi), (np.pi/6 + 15/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_4))
z = rho * (np.cos(phi_4) + 1j * np.sin(phi_4))
plt.plot(z.real, z.imag, color = 'blue', linewidth = 3)

phi_5 = np.linspace((-np.pi/6 + 20/3 * np.pi), (np.pi/6 + 20/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_5))
z = rho * (np.cos(phi_5) + 1j * np.sin(phi_5))
plt.plot(z.real, z.imag, color = 'blue', linewidth = 3)

phi_6 = np.linspace((-np.pi/6 + 25/3 * np.pi), (np.pi/6 + 25/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_6))
z = rho * (np.cos(phi_6) + 1j * np.sin(phi_6))
plt.plot(z.real, z.imag, color = 'blue', linewidth = 3)


#построение координатной сетки до отображения
x = np.linspace(-1, 1, 50)
y = np.linspace(0, 0, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.2, 0.2, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.4, 0.4, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.6, 0.6, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.8, 0.8, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.2, -0.2, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.4, -0.4, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.6, -0.6, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.8, -0.8, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (10, 10))

#зададим аргумент, модуль и отображение комплексного числа
phi = np.linspace(0, 10*np.pi, 500)
rho = 0.9*abs(np.cos(3/5 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))
f = 2*np.exp(-z)

#построение образа розы
plt.plot(f.real, f.imag, color = 'purple', linewidth = 0.8)

plt.xlabel("Re(f(z))")
plt.ylabel("Im(f(z))")

#построение образа границы розы
phi_1 = np.linspace(-np.pi/6, np.pi/6, 50)
rho = 0.9*abs(np.cos(3/5 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
f = 2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'purple', linewidth = 3)

phi_2 = np.linspace((-np.pi/6 + 5/3 * np.pi), (np.pi/6 + 5/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_2))
z = rho * (np.cos(phi_2) + 1j * np.sin(phi_2))
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'purple', linewidth = 3)

phi_3 = np.linspace((-np.pi/6 + 10/3 * np.pi), (np.pi/6 + 10/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_3))
z = rho * (np.cos(phi_3) + 1j * np.sin(phi_3))
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'purple', linewidth = 3)

phi_4 = np.linspace((-np.pi/6 + 15/3 * np.pi), (np.pi/6 + 15/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_4))
z = rho * (np.cos(phi_4) + 1j * np.sin(phi_4))
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'purple', linewidth = 3)

phi_5 = np.linspace((-np.pi/6 + 20/3 * np.pi), (np.pi/6 + 20/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_5))
z = rho * (np.cos(phi_5) + 1j * np.sin(phi_5))
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'purple', linewidth = 3)

phi_6 = np.linspace((-np.pi/6 + 25/3 * np.pi), (np.pi/6 + 25/3 * np.pi), 50)
rho = 0.9*abs(np.cos(3/5 * phi_6))
z = rho * (np.cos(phi_6) + 1j * np.sin(phi_6))
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'purple', linewidth = 3)


#построение координатной сетки после отображения
x = np.linspace(-2, 2, 50)
y = np.linspace(0, 0, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.2, 0.2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.4, 0.4, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.6, 0.6, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.8, 0.8, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(1, 1, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.2, -0.2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.4, -0.4, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.6, -0.6, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.8, -0.8, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-1, -1, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(1, 1, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(1.25, 1.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-1, -1, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f=2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-1.25, -1.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = 2*np.exp(-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

plt.xlim(0.7, 5)
plt.ylim(-3, 3)

plt.show()

# %% [markdown]
# # Задание 2

# %%
theta = np.linspace(0, 14*np.pi, 1000)
r1 = 2.0 * np.abs(np.cos(5 * theta/3))
r2 = 0.4 * np.abs(np.cos(9 * theta/7))
x1, y1 = r1 * np.cos(theta), r1 * np.sin(theta)
x2, y2 = r2 * np.cos(theta), r2 * np.sin(theta)
z1 = x1 + 1j * y1
z2 = x2 + 1j * y2

def g(z):
    return (4*z - 1) / (4 - z)

fig, ax = plt.subplots(1, 2, figsize=(10,5))
ax[0].plot(x1, y1, color='olive', linewidth=1)
ax[0].plot(x2, y2, color='y', linewidth=1)
ax[0].set_xlim(-1, 1)
ax[0].set_ylim(-1, 1)
ax[0].set_xlabel('Re(z)')
ax[0].set_ylabel('Im(z)')
ax[0].grid()

ax[1].plot(g(z1).real, g(z1).imag, color='teal', linewidth=1)
ax[1].plot(g(z2).real, g(z2).imag, color='c', linewidth=1)
ax[1].set_xlim(-1, 1)
ax[1].set_ylim(-1, 1)
ax[1].set_xlabel('Re(z)')
ax[1].set_ylabel('Im(z)')
ax[1].grid()
plt.show()

# %%
def hsl_coloring(z, a=1):
    h = np.angle(z) / (2 * np.pi) + 0.5  
    s = np.ones_like(z, dtype=float) 
    l = (np.abs(z)**a) / (np.abs(z)**a + 1)
    return np.dstack((h, s, l)).astype(float)

def to_rgb(hsl):
    h, s, l = hsl[..., 0], hsl[..., 1], hsl[..., 2]
    c = (1 - np.abs(2 * l - 1)) * s
    x = c * (1 - np.abs(np.mod(h * 6, 2) - 1))
    m = l - c / 2

    rgb = np.zeros(hsl.shape, dtype=float)

    h = h * 6
    i = (h < 1)
    rgb[i] = np.dstack((c[i], x[i], np.zeros_like(c[i]))) + m[i][..., np.newaxis]

    i = (1 <= h) & (h < 2)
    rgb[i] = np.dstack((x[i], c[i], np.zeros_like(c[i]))) + m[i][..., np.newaxis]

    i = (2 <= h) & (h < 3)
    rgb[i] = np.dstack((np.zeros_like(c[i]), c[i], x[i])) + m[i][..., np.newaxis]

    i = (3 <= h) & (h < 4)
    rgb[i] = np.dstack((np.zeros_like(c[i]), x[i], c[i])) + m[i][..., np.newaxis]

    i = (4 <= h) & (h < 5)
    rgb[i] = np.dstack((x[i], np.zeros_like(c[i]), c[i])) + m[i][..., np.newaxis]

    i = (5 <= h) & (h < 6)
    rgb[i] = np.dstack((c[i], np.zeros_like(c[i]), x[i])) + m[i][..., np.newaxis]

    return rgb

alpha1, beta1, alpha2, beta2 = 0.4, 9/7, 2.0, 5/3
grid_size = 1000
x = np.linspace(-2, 2, grid_size)
y = np.linspace(-2, 2, grid_size)
X, Y = np.meshgrid(x, y)
Z = X + 1j * Y

R = np.abs(Z)
Arg = np.angle(Z)
max_cos1 = np.abs(np.cos(beta1 * (Arg + 2 * np.pi * np.arange(-10, 11)[:, None, None]))).max(axis=0)
max_cos2 = np.abs(np.cos(beta2 * (Arg + 2 * np.pi * np.arange(-10, 11)[:, None, None]))).max(axis=0)
mask = (alpha1 * max_cos1 <= R) & (R <= alpha2 * max_cos2)

hsl = hsl_coloring(Z)
rgb = to_rgb(hsl)
rgb[~mask] = 1  



def conformal_map(z):
    return (4*z - 1) / (4 - z)

w = conformal_map(Z)
w = np.conj(W)

R_w = np.abs(W)
Arg_w = np.angle(W)
max_cos1_w = np.abs(np.cos(beta1 * (Arg_w + 2 * np.pi * np.arange(-10, 11)[:, None, None]))).max(axis=0)
max_cos2_w = np.abs(np.cos(beta2 * (Arg_w + 2 * np.pi * np.arange(-10, 11)[:, None, None]))).max(axis=0)
mask_w = (alpha1 * max_cos1_w <= R_w) & (R_w <= alpha2 * max_cos2_w)

hsl_w = hsl_coloring(W)
rgb_w = to_rgb(hsl_w)
rgb_w[~mask_w] = 1 

fig, ax = plt.subplots(1, 2, figsize=(10,5))
ax[0].imshow(rgb, extent=[-1, 1, -1, 1])
ax[0].set_title('Прообраз розы')
ax[0].set_xlabel('Re(z)')
ax[0].set_ylabel('Im(z)')

ax[1].imshow(rgb_w, extent=[-1, 1, -1, 1])
ax[1].set_title('Образ розы')
ax[1].set_xlabel('Re(z)')
ax[1].set_ylabel('Im(z)')
plt.show()
